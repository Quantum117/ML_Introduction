# %%
import numpy as np

# %%
from sklearn.tree import  DecisionTreeClassifier

# %%
def gini_impurity(y):
    """Calculate Gini impurity for a node"""
    if len(y) == 0:
        return 0
    proportions = np.bincount(y) / len(y)
    return 1 - np.sum(proportions ** 2)

def entropy(y):
    counts = np.bincount(y)
    p = counts / counts.sum()
    p = p[p > 0]
    return np.sum(1/(p * np.log2(p)))

# %%
class Node:
    def __init__(self,feature=None, threshold=None, left=None, right=None,*, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value =None

    def is_leaf(self):
        return self.value is None

    #def is_root(self, Node):

# %%
class DecisionTreeClassifier:
    """Splits the data into two nodes at every step, minimizing gini impurity. IF stopping criteria will be reached it makes a leaf , each data sample in a leaf is considered the same class ( through majority voting ) """
    def __init__(self, max_depth = None, min_samples_split = 2, n_features = None):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.n_features = n_features
        self.tree = None
        self.classes = None

    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        self.classes = np.unique(y)

    def predict(self, X):
        pass

# %%
from sklearn.preprocessing import LabelEncoder

y_raw = [1.2, 2.2, 2.2, 1.1]
y = LabelEncoder().fit_transform(y_raw)
y
# Out:
# array([1, 2, 2, 0])

# %%
np.bincount(y)
# Out:
# array([1, 1, 2])
