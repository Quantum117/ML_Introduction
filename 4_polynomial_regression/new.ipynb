# %%
import pandas as pd

# %%
df = pd.read_csv('housing_data.csv')
df

# %%
df['Xonalar soni'].value_counts() # prints frequency table from pandas series
# we need to remove houses that have 5 rooms or more
# Out:
# Xonalar soni
# 2     460
# 3     394
# 1     161
# 4     131
# 5      19
# 6       7
# 8       3
# 60      1
# 7       1
# Name: count, dtype: int64

# %%
room_filter =df['Xonalar soni'] < 5
area_filter = (df['Umumiy maydon'] >25) & (df['Umumiy maydon'] < 131)
floor_filter = df['Qavati'] < 16
building_floor = df['Uy qavatliligi'] < 19

# %%
df2 = df[room_filter]
df2
# Out:
#              Turarjoy turi  Xonalar soni  Umumiy maydon  Qavati  \
# 0         Ikkilamchi bozor             4           95.0       2
# 1     Yangi qurilgan uylar             3           76.0       8
# 2     Yangi qurilgan uylar             3           74.0       8
# 3     Yangi qurilgan uylar             2           52.0      11
# 4     Yangi qurilgan uylar             2           70.0      40
# ...                    ...           ...            ...     ...
# 1172      Ikkilamchi bozor             2           40.0       2
# 1173      Ikkilamchi bozor             3           45.0       4
# 1174      Ikkilamchi bozor             2           46.0       1
# 1175  Yangi qurilgan uylar             1           28.0       3
# 1176      Ikkilamchi bozor             3           68.0       4
#
#       Uy qavatliligi Mebelli           Tuman  Narx
# 0                  9      Ha       Yunusobod   165
# 1                 10      Ha  Mirzo-Ulug‘bek   185
# ...

# %%
df['Tuman'].value_counts()
# Out:
# Tuman
# Mirzo-Ulug‘bek    215
# Yashnobod         179
# Yakkasaroy        168
# Yunusobod         162
# Mirobod           111
# Sirg‘ali          101
# Shayxontohur       92
# Chilonzor          92
# Olmazor            27
# Bektemir           16
# Uchtepa            14
# Name: count, dtype: int64
